# %% [markdown]
# <a href="https://colab.research.google.com/github/2410072/Python-Lesson/blob/main/Chainer_note.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Chainer note

# %%
a = 1

# %%
a
# Out:
# 1

# %%
print(a)
# Out:
# 1

# %%
a = 1
b = 1.2
c = "Chainer"

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
a, b = 1, 1.2

# %%
a, b, c = 1, 1.2, "Chainer"

# %%
1+1
# Out:
# 2

# %%
1 + 1
# Out:
# 2

# %%
a + 2
# Out:
# 3

# %%
a + b
# Out:
# 2.2

# %%
a * b
# Out:
# 1.2

# %%
a // b
# Out:
# 0.0

# %%
6 // 3
# Out:
# 2

# %%
6 / 3
# Out:
# 2.0

# %%
6 % 3
# Out:
# 0

# %%
6 ** 3
# Out:
# 216

# %%
c * 3
# Out:
# 'ChainerChainerChainer'

# %%
type(str(a))
# Out:
# str

# %%
count = 0
count = count + 1
count
# Out:
# 1

# %%
count = 0
count += 1
count
# Out:
# 1

# %%
9 % 2
# Out:
# 1

# %%
1 < 2
# Out:
# True

# %%
type(1<2)
# Out:
# bool

# %%
2==5
# Out:
# False

# %%
2 != 4
# Out:
# True

# %%
3 >= 3
# Out:
# True

# %%
"test" == "test"
# Out:
# True

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Hello\tWorld")
# Out:
# Hello	World

# %%
d = "Hello\nWorld"

# %%
d
# Out:
# 'Hello\nWorld'

# %%
print(d)
# Out:
# Hello
# World

# %%
name = "Chainer"
name
# Out:
# 'Chainer'

# %%
name.lower()
# Out:
# 'chainer'

# %%
name.upper()
# Out:
# 'CHAINER'

# %%
name = "Chainer"
'{} Welcome to tutorial'.format(name)
# Out:
# 'Chainer Welcome to tutorial'

# %%
name1 = 'Chainer'
name2 = ' '
name3 = 'tutorial'
'Welcome to {}{}{}'.format(name1, name2, name3)
# Out:
# 'Welcome to Chainer tutorial'

# %%
config
# Out:
# Available objects for config:
#      AliasManager
#      ColabHistoryManager
#      ColabKernelApp
#      DisplayFormatter
#      IPCompleter
#      InlineBackend
#      LoggingMagics
#      MagicsManager
#      OSMagics
#      PrefilterManager
#      ScriptMagics
#      Shell
#      StoreMagics

# %%
0.5.as_integer_ratio()
# Out:
# (1, 2)

# %%
0.25.as_integer_ratio()
# Out:
# (1, 4)

# %%
numbers = [4, 5, 6, 7]
print(numbers)
# Out:
# [4, 5, 6, 7]

# %%
type(numbers)
# Out:
# list

# %%
len(numbers)
# Out:
# 4

# %%
numbers[0]
# Out:
# 4

# %%
numbers[2]
# Out:
# 6

# %%
numbers[1]
# Out:
# 5

# %%
numbers[1] = 10

# %%
numbers
# Out:
# [4, 10, 6, 7]

# %%
numbers[-1]
# Out:
# 7

# %%
numbers[-3]
# Out:
# 10

# %%
numbers[0:2]
# Out:
# [4, 10]

# %%
numbers[:2]
# Out:
# [4, 10]

# %%
ns = numbers
ns
# Out:
# [4, 10, 6, 7]

# %%
ns[:2]
# Out:
# [4, 10]

# %%
del ns

# %%
numbers[1:]
# Out:
# [10, 6, 7]

# %%
numbers[:]
# Out:
# [4, 10, 6, 7]

# %%
array = ['hello', 'world']
array
# Out:
# ['hello', 'world']

# %%
array = [1, 1.2, 'Chainer']
array
# Out:
# [1, 1.2, 'Chainer']

# %%
array = [[1, 1.2, 'Chainer'], [2, 2.2, 'Tutorial']]
array
# Out:
# [[1, 1.2, 'Chainer'], [2, 2.2, 'Tutorial']]

# %%
array.append(2.5)
array
# Out:
# [[1, 1.2, 'Chainer'], [2, 2.2, 'Tutorial'], 2.5]

# %%
array
# Out:
# [[1, 1.2, 'Chainer'], [2, 2.2, 'Tutorial'], 2.5]

# %%
array = []

array.append('Chainer')
array.append('Tutorial')
array
# Out:
# ['Chainer', 'Tutorial']

# %%
array = (4, 5, 6, 7)
array
# Out:
# (4, 5, 6, 7)

# %%
type(array)
# Out:
# tuple

# %%
array[0]
# Out:
# 4

# %%
array[:3]
# Out:
# (4, 5, 6)
